# %% [markdown]
# **Import Libraries:**

# %%
import numpy as np 
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

# %% [markdown]
# **Reading the data:**

# %%
heart = pd.read_csv("C:\\Users\HamidReza\Downloads\heart.csv")
heart
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  caa  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    0
# 3     56    1   1     120   236    0        1       178     0      0.8    0
# 4     57    0   0     120   354    0        1       163     1      0.6    0
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    0
# 299   45    1   3     110   264    0        1       132     0      1.2    0
# 300   68    1   0     144   193    1        1       141     0      3.4    2
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      output
# 0         1
# 1         1
# 2         1
# ...

# %% [markdown]
# **Discovering the features types:**

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  caa       303 non-null    int64
#  11  output    303 non-null    int64
# dtypes: float64(1), int64(11)
# memory usage: 28.5 KB

# %% [markdown]
# **Discovering the missed values:**

# %%
heart.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# caa         0
# output      0
# dtype: int64

# %% [markdown]
# **Discovering the duplicate values:**

# %%
heart.duplicated().sum()
# Out:
# 1

# %%
heart.drop_duplicates(inplace=True)
heart
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  caa  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    0
# 3     56    1   1     120   236    0        1       178     0      0.8    0
# 4     57    0   0     120   354    0        1       163     1      0.6    0
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    0
# 299   45    1   3     110   264    0        1       132     0      1.2    0
# 300   68    1   0     144   193    1        1       141     0      3.4    2
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      output
# 0         1
# 1         1
# 2         1
# ...

# %%
heart.hist(figsize=(20,15))
plt.show()

# %%
heart.describe()
# Out:
#              age         sex          cp      trtbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         caa      output
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    0.718543    0.543046
# ...

# %%
#heart.drop(columns = ["Gender"] , inplace=True )

# %% [markdown]
# **Model Prepration:**

# %%
from sklearn.model_selection import train_test_split
Y = heart["output"]
X = heart.drop('output',axis=1)
X_train, X_test , Y_train,Y_test = train_test_split(X, Y, test_size=0.20, random_state=2)

# %% [markdown]
# Y_train = heart["output"]
# X_train = heart.drop(["output"],axis = 1)

# %%
X_train
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  caa
# 237   60    1   0     140   293    0        0       170     0      1.2    2
# 106   69    1   3     160   234    1        0       131     0      0.1    1
# 10    54    1   0     140   239    0        1       160     0      1.2    0
# 153   66    0   2     146   278    0        0       152     0      0.0    1
# 77    59    1   1     140   221    0        1       164     1      0.0    0
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 75    55    0   1     135   250    0        0       161     0      1.4    0
# 22    42    1   0     140   226    0        1       178     0      0.0    0
# 72    29    1   1     130   204    0        0       202     0      0.0    0
# 15    50    0   2     120   219    0        1       158     0      1.6    0
# 169   53    1   0     140   203    1        0       155     1      3.1    0
#
# [241 rows x 11 columns]

# %%
Y_train
# Out:
# 237    0
# 106    1
# 10     1
# 153    1
# 77     1
#       ..
# 75     1
# 22     1
# 72     1
# 15     1
# 169    0
# Name: output, Length: 241, dtype: int64

# %%
X_test
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  caa
# 99    53    1   2     130   246    1        0       173     0      0.0    3
# 296   63    0   0     124   197    0        1       136     1      0.0    0
# 89    58    0   0     100   248    0        0       122     0      1.0    0
# 30    41    0   1     105   198    0        1       168     0      0.0    1
# 297   59    1   0     164   176    1        0        90     0      1.0    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 174   60    1   0     130   206    0        0       132     1      2.4    2
# 94    45    0   1     112   160    0        1       138     0      0.0    0
# 161   55    0   1     132   342    0        1       166     0      1.2    0
# 217   63    1   0     130   330    1        0       132     1      1.8    3
# 91    57    1   0     132   207    0        1       168     1      0.0    0
#
# [61 rows x 11 columns]

# %%
from collections import Counter
Counter(Y_train)
# Out:
# Counter({0: 105, 1: 136})

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)  
X_test = scaler.transform(X_test)

# %%
#after scaling
X_train
# Out:
# array([[ 0.58335005,  0.6983225 , -0.92981682, ..., -0.66566791,
#          0.13126739,  1.38002844],
#        [ 1.56419212,  0.6983225 ,  1.94307874, ..., -0.66566791,
#         -0.79670557,  0.34069452],
#        [-0.07054466,  0.6983225 , -0.92981682, ..., -0.66566791,
#          0.13126739, -0.6986394 ],
#        ...,
#        [-2.79510595,  0.6983225 ,  0.02781503, ..., -0.66566791,
#         -0.88106675, -0.6986394 ],
#        [-0.50647446, -1.43200311,  0.98544689, ..., -0.66566791,
#          0.46871211, -0.6986394 ],
#        [-0.17952711,  0.6983225 , -0.92981682, ...,  1.50225056,
#          1.73412979, -0.6986394 ]])

# %%
#after scaling
X_test
# Out:
# array([[-0.17952711,  0.6983225 ,  0.98544689, -0.11925025, -0.01043967,
#          2.42604911, -0.98171831,  0.98524259, -0.66566791, -0.88106675,
#          2.41936236],
#        [ 0.91029741, -1.43200311, -0.92981682, -0.45538254, -0.95152369,
#         -0.41219281,  0.92629873, -0.6465197 ,  1.50225056, -0.88106675,
#         -0.6986394 ],
#        [ 0.36538515, -1.43200311, -0.92981682, -1.79991169,  0.02797193,
#         -0.41219281, -0.98171831, -1.26394327, -0.66566791, -0.03745496,
#         -0.6986394 ],
#        [-1.48731653, -1.43200311,  0.02781503, -1.51980145, -0.93231789,
#         -0.41219281,  0.92629873,  0.76473417, -0.66566791, -0.88106675,
#          0.34069452],
#        [ 0.4743676 ,  0.6983225 , -0.92981682,  1.78549938, -1.35484541,
#          2.42604911, -0.98171831, -2.67519714, -0.66566791, -0.03745496,
#          1.38002844],
#        [ 0.36538515, -1.43200311, -0.92981682,  2.12163166, -0.41376139,
# ...

# %% [markdown]
# **Modeling:**

# %%
#Logistic Regression(LR)

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score
LR = LogisticRegression()
LR.fit(X_train, Y_train)
LR_predict = LR.predict(X_test)
LR_conf_matrix = confusion_matrix(Y_test, LR_predict)
accuracy = accuracy_score(Y_test, LR_predict)
precision = precision_score(Y_test, LR_predict)
recall = recall_score(Y_test, LR_predict)

print("Accuracy of Logistic Regression:",accuracy*100)
print("Accuracy of Logistic Regression:",precision*100)
print("Accuracy of Logistic Regression:",recall*100)
# Out:
# Accuracy of Logistic Regression: 90.1639344262295
# Accuracy of Logistic Regression: 82.35294117647058
# Accuracy of Logistic Regression: 100.0

# %%
#Support Vector Classifier(SVC)

from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, Y_train)
svc_predict = svc.predict(X_test)
svc_conf_matrix = confusion_matrix(Y_test, svc_predict)
svc_acc_score = accuracy_score(Y_test, svc_predict)

print("confussion matrix:")
print(svc_conf_matrix,"\n")
print("Accuracy of Support Vector Classifier:",svc_acc_score*100)
# Out:
# confussion matrix:
# [[26  7]
#  [ 0 28]]
#
# Accuracy of Support Vector Classifier: 88.52459016393442
